# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([100,200,300],
            index=['A','B','C'])
print(s)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data={'maths':89,
     'physics':90,
     'chemistry':83
    }
s=pd.Series(data)
print(s)
# Out:
# maths        89
# physics      90
# chemistry    83
# dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s[2])
# Out:
# 30

# %%
s=pd.Series([100,200,300],index=['A','B','C'])
print(s['B'])
# Out:
# 200

# %%
s=pd.Series([100,200,300],index=['A','B','C'])
print(s[['A','B']])
# Out:
# A    100
# B    200
# dtype: int64

# %%
print(s.size)
# Out:
# 3

# %%
print(s.shape)
# Out:
# (3,)

# %%
print(s.dtype)
# Out:
# int64

# %%
s=pd.Series([10,20,30,40])
print(s+10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
print(s*5)
# Out:
# 0     50
# 1    100
# 2    150
# 3    200
# dtype: int64

# %%
print("sum=",s.sum())
print("mean=",s.mean())
print("minimum=",s.min())
print("maximum=",s.max())
# Out:
# sum= 100
# mean= 25.0
# minimum= 10
# maximum= 40

# %%
data={"roll number":[101,102,103,104,105,],
      "name":["arun","priya","rahul","vaish","vijay"],
      "marks":[78,99,87,78,90]
     }
df=pd.DataFrame(data)
print(df)
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 1          102  priya     99
# 2          103  rahul     87
# 3          104  vaish     78
# 4          105  vijay     90

# %%
df=pd.DataFrame(data,
                index=['A','B','C'])
print(df)
# Out:
#    roll number   name  marks
# A          101   arun     78
# B          102  priya     99
# C          103  rahul     87

# %%
print(df.columns)
# Out:
# Index(['roll number', 'name', 'marks'], dtype='object')

# %%
print(df.index)
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
print(df.dtypes)
# Out:
# roll number     int64
# name           object
# marks           int64
# dtype: object

# %%
print(df[['name','marks']])
# Out:
#     name  marks
# A   arun     78
# B  priya     99
# C  rahul     87

# %%
print(df['name'])
# Out:
# A     arun
# B    priya
# C    rahul
# Name: name, dtype: object

# %%
print(df.loc[0])
# Out:
# roll number     101
# name           arun
# marks            78
# Name: 0, dtype: object

# %%
print(df.loc[[0,2]])
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 2          103  rahul     87

# %%
print(df.iloc[1])
# Out:
# roll number      102
# name           priya
# marks             99
# Name: 1, dtype: object

# %%
print(df.iloc[[0,2]])
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 2          103  rahul     87

# %%
print(df.iloc[0:2,1:3])
# Out:
#     name  marks
# 0   arun     78
# 1  priya     99

# %%
df['grade']=['A','A+','B']
print(df)
# Out:
#    roll number   name  marks grade
# 0          101   arun     78     A
# 1          102  priya     99    A+
# 2          103  rahul     87     B

# %%
df['marks']=df['marks']+5
print(df)
# Out:
#    roll number   name  marks
# 0          101   arun     88
# 1          102  priya    109
# 2          103  rahul     97

# %%
df.drop('grade',
        axis=1,
        inplace=True)
print(df)
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 1          102  priya     99
# 2          103  rahul     87

# %%
print(df['marks'].sum())
# Out:
# 264

# %%
print(df['marks'].mean())
# Out:
# 88.0

# %%
print(df['marks'].max())
# Out:
# 99

# %%
print(df['marks'].min())
# Out:
# 78

# %%
df.sort_values('marks')
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 2          103  rahul     87
# 1          102  priya     99

# %%
df.sort_values('marks',ascending=False)
# Out:
#    roll number   name  marks
# 1          102  priya     99
# 2          103  rahul     87
# 0          101   arun     78

# %%
print(df[df['marks']>80])
# Out:
#    roll number   name  marks
# B          102  priya     99
# C          103  rahul     87

# %%
print(df[df['marks']<90])
# Out:
#    roll number   name  marks
# A          101   arun     78
# C          103  rahul     87

# %%
df.head()
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 1          102  priya     99
# 2          103  rahul     87
# 3          104  vaish     78
# 4          105  vijay     90

# %%
df.tail()
# Out:
#    roll number   name  marks
# 0          101   arun     78
# 1          102  priya     99
# 2          103  rahul     87
# 3          104  vaish     78
# 4          105  vijay     90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   roll number  5 non-null      int64
#  1   name         5 non-null      object
#  2   marks        5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
data={"roll number":[1,2,3,4,5,6,],
      "name":["arun","priya","rahul","vaish","vijay","rishi"],
      "department":["cs","ai","bca","mech","bcom","bba"],
      "cgpa":[7.7,9.6,6,9.9,7,7.8],
      "marks":[79,98,67,99,70,89]
     }
df=pd.DataFrame(data)
print(df)
# Out:
#    roll number   name department  cgpa  marks
# 0            1   arun         cs   7.7     79
# 1            2  priya         ai   9.6     98
# 2            3  rahul        bca   6.0     67
# 3            4  vaish       mech   9.9     99
# 4            5  vijay       bcom   7.0     70
# 5            6  rishi        bba   7.8     89

# %%
print(df["marks"].sum())
# Out:
# 502

# %%
print(df["marks"].mean())
# Out:
# 83.66666666666667

# %%
print(df["marks"].min())
# Out:
# 67

# %%
print(df["marks"].max())
# Out:
# 99
